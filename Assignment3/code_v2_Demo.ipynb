# %%
# importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import scale
from math import exp
from collections import defaultdict 
from sklearn.metrics.pairwise import chi2_kernel
# import warnings
# warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/Google Colab Notebooks/DMW/SVMC Markov/letter-recognition.csv')

# feature names were like - 'letter ' changed it to 'letter'
df.columns = ['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar',
       'ybar', 'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge',
       'xedgey', 'yedge', 'yedgex']
print(df.columns)
# Out:
# Index(['letter', 'xbox', 'ybox', 'width', 'height', 'onpix', 'xbar', 'ybar',
#        'x2bar', 'y2bar', 'xybar', 'x2ybar', 'xy2bar', 'xedge', 'xedgey',
#        'yedge', 'yedgex'],
#       dtype='object')

# %%
print(f"Number of rows = {df.shape[0]}, cols = {df.shape[1]}")
df.head()
# Out:
# Number of rows = 20000, cols = 17
#   letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 0      T     2     8      3       5  ...       8      0       8      0       8
# 1      I     5    12      3       7  ...       9      2       8      4      10
# 2      D     4    11      6       8  ...       7      3       7      3       9
# 3      N     7    11      6       6  ...      10      6      10      2       8
# 4      G     2     1      3       1  ...       9      1       7      5      10
#
# [5 rows x 17 columns]

# %%
# number of different classes
classes = df['letter'].unique()
print(f'Number of different labels in dataset = {len(classes)}')
classes.sort()
for cls in classes:
    rows = len(df[df['letter'] == cls])
    print(f'Number of data points in class {cls} = {rows}')
# Out:
# Number of different labels in dataset = 26
# Number of data points in class A = 789
# Number of data points in class B = 766
# Number of data points in class C = 736
# Number of data points in class D = 805
# Number of data points in class E = 768
# Number of data points in class F = 775
# Number of data points in class G = 773
# Number of data points in class H = 734
# Number of data points in class I = 755
# Number of data points in class J = 747
# Number of data points in class K = 739
# Number of data points in class L = 761
# Number of data points in class M = 792
# Number of data points in class N = 783
# Number of data points in class O = 753
# Number of data points in class P = 803
# Number of data points in class Q = 783
# Number of data points in class R = 758
# Number of data points in class S = 748
# Number of data points in class T = 796
# Number of data points in class U = 813
# Number of data points in class V = 764
# Number of data points in class W = 752
# Number of data points in class X = 787
# Number of data points in class Y = 786
# Number of data points in class Z = 734

# %%
# Preparing the dataset

# binary labeling of the dataset
df1 = df.copy()

# one alphabet will be treated as positive sample and others as negative sample
alphabet = 'A'  
df1.loc[(df1.letter != alphabet),'letter'] = -1
df1.loc[(df1.letter == alphabet),'letter'] = 1

# we will make number of positve samples = number of negative samples otherwise
# otherwise the dataset will have huge number of negative samples which will slow
# down the sampling process
pos = df1[df1['letter']==1].sample(frac=1)
# we need roughly only 1/25 of total negative samples 
neg = df1[df1['letter']==-1].sample(frac=1/25)

df_final = pos.append(neg,ignore_index=True)
print(f"Length of final dataset {len(df_final)}")
df_final.head()
# Out:
# Length of final dataset 1557
#   letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 0      1     3     8      5       5  ...       8      2       7      1       8
# 1      1     3     3      5       4  ...       8      2       7      2       8
# 2      1     4    10      5       7  ...       8      2       7      2       8
# 3      1     2     6      4       4  ...       8      2       6      2       9
# 4      1     2     1      4       2  ...       8      2       6      2       7
#
# [5 rows x 17 columns]

# %%
# train test split
df_final_train, df_final_test = train_test_split(df_final, test_size=0.3, random_state=42)


# we need to generate a preliminary model first = f0 using N1(< M) datapoints
M = 1000
N1 = round(M * 0.75)

# we will extract N1 data points randomly
df_sample = df_final_train.sample(n=N1)

df_sample_features = df_sample.loc[:, df_sample.columns != 'letter']
df_sample_target = df_sample.loc[:, ['letter']]

print(df_sample_features.head())
print(df_sample_target.head())
# Out:
#       xbox  ybox  width  height  onpix  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 917      7    10      7       8      4  ...       8      2      10      1       8
# 25       2     7      4       5      2  ...       9      2       6      3       9
# 1403     5     8      8       6      5  ...      11      5       8      2       7
# 195      3     7      5       5      3  ...       9      3       5      3       8
# 1480     3     6      4       4      3  ...       7      3       8      2       8
#
# [5 rows x 16 columns]
#      letter
# 917      -1
# 25        1
# 1403     -1
# 195       1
# 1480     -1

# %%
# Markov Sampling 

# Step1 
# generating priliminary model f0

# scale? is it required
df_sample_features = scale(df_sample_features)
df_sample_target = df_sample_target.astype('int')

f0 = SVC(kernel = 'linear')
f0.fit(df_sample_features, df_sample_target.values.ravel())
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Step 2
# draw one sample randomly

m_pos, m_neg = 0, 0
zt = df_final_train.sample(n=1)
print(zt)
if M%2 == 0:
  label = zt.iloc[0]['letter']
  print("")
  if label == 1:
    m_pos += 1
  else:
    m_neg += 1
# Out:
#     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 996     -1     6     9      4       4  ...       8      2       9      5       9
#
# [1 rows x 17 columns]

# %%
def predict(z):
  x = zt.loc[:, zt.columns != 'letter']
  y = zt.loc[:, zt.columns == 'letter']
  # doubtful
  fx = f0.predict(x)
  return fx

# %%
# returns the loss value calculated using model f0
def loss(z):
  y = z.iloc[0]['letter']
  # doubtful
  fx = predict(z)

  if fx*y > 1:
    return 0
  else:
    return 1-fx*y

# %%
def calculate_P(zs,zst):
  P = exp(-loss(zs))/exp(-loss(zt))
  return P

# %%
def acceptance_prob(zs,zt):
  ys = zs.iloc[0]['letter']
  yt = zt.iloc[0]['letter']

  fs = predict(zs)
  ft = predict(zt)

  return exp(-fs*ys)/exp(-ft*yt)

# %%
# Step 3
# should its type be pandas.dataframe?
sampled_data = []
# keep count of how many times a sample is rejected
rejected = defaultdict(int)

# all variable names are as given in paper
# constants used in algorithm, see section 4A point 1 in paper
K = 5
Q = 1.2
while m_pos < M//2 or m_neg < M//2:
  # draw one sample randomly = z_star(zs)
  zs = df_final_train.sample(n=1)
  print("considering ",zs)
  P = calculate_P(zs,zt)
  
  # yt corresponds to Y of zt
  yt = zt.iloc[0]['letter']
  ys = zs.iloc[0]['letter']

  # alpha is the acceptance probability of zs, given in step 5
  alpha = P
  # need to convert it to tuple so that it becomes hashable
  tpl = tuple(zs.to_records(index=False)[0])

  if P==1 and yt==-1 and ys==-1:
    alpha = acceptance_prob(zs,zt)  # P'
  elif P==1 and yt==1 and ys==1:    
    alpha = acceptance_prob(zs,zt)  # P'
  elif (P==1 and yt*ys==-1) or P<1 :
    alpha = P                       # P
  elif rejected[tpl]>K:
    alpha = QP                      # P''
                         
  if alpha>1:
    alpha=1

  print(f"alpha {alpha}")
  if np.random.random() < alpha:
    sampled_data.append(zs)
  else:
    rejected[tpl]+=1

  if yt == 1:
    m_pos += 1 
  else:
    m_neg += 1
  
  # for next iteration 
  zt = zs
  print(f"Positive = {m_pos} Negative = {m_neg}")
# Out:
# Streaming output truncated to the last 5000 lines.
# alpha 0.1353352832366127
# Positive = 96 Negative = 84
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 994     -1     5     9      6       8  ...       9      5      10      9      11
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 97 Negative = 84
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 732      1     3     4      5       3  ...       9      4       5      2       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 97 Negative = 85
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1393     -1     6    10      9       7  ...       6      1       8      6       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 98 Negative = 85
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 893     -1     6     9      8       8  ...       8      4       7      7       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 98 Negative = 86
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 102      1     5     9      9       7  ...       7      6       7      7       2
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 98 Negative = 87
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1483     -1     3     4      4       3  ...       7      2      11      1       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 99 Negative = 87
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 22      1     2     4      4       6  ...       8      3       6      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 99 Negative = 88
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 911     -1     4     8      4       6  ...       6      1      11      2       6
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 100 Negative = 88
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 445      1     3     6      6       4  ...       6      2       6      4       6
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 100 Negative = 89
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 283      1     2     3      3       1  ...       9      1       6      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 101 Negative = 89
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 98      1     4     5      6       4  ...       7      4       9      4       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 102 Negative = 89
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 401      1     2     2      4       4  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 103 Negative = 89
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1530     -1     5     5      6       4  ...       9      3       9      3       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 104 Negative = 89
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 581      1     3     6      5       5  ...       5      4      10      4       5
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 104 Negative = 90
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1235     -1     4     5      5       3  ...       9      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 105 Negative = 90
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1010     -1     4     8      6       6  ...      10      4       8      5       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 105 Negative = 91
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 510      1     4     8      6       6  ...       8      2       7      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 105 Negative = 92
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 296      1     3     7      4       5  ...       8      2       6      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 106 Negative = 92
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 853     -1     1     1      2       1  ...       5      1       9      3       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 107 Negative = 92
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1212     -1     7     8      7       6  ...       8      6      12      2       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 107 Negative = 93
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 926     -1     5     7      7       5  ...       8      3       6      5      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 107 Negative = 94
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 762      1     2     4      4       3  ...       8      2       7      3       6
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 107 Negative = 95
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 384      1     7    13      7       7  ...      10      5       3      4      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 108 Negative = 95
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 66      1     2     4      4       3  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 109 Negative = 95
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1307     -1     6    10      6       8  ...       8      9       6      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 110 Negative = 95
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 863     -1     5    10      6       8  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 110 Negative = 96
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 157      1     3     7      5       5  ...       8      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 110 Negative = 97
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 110      1     3     8      5       6  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 111 Negative = 97
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 686      1     3     6      5       4  ...       9      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 112 Negative = 97
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 454      1     3     4      5       2  ...       8      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 113 Negative = 97
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1191     -1     5    10      7       7  ...       7      3       8      3       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 114 Negative = 97
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 991     -1     1     1      1       1  ...      10      3       8      2      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 114 Negative = 98
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 795     -1     5     9      8       7  ...       5      6       9      1       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 114 Negative = 99
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1444     -1     2     2      2       3  ...       7      2       8      8       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 114 Negative = 100
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 384      1     7    13      7       7  ...      10      5       3      4      10
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 114 Negative = 101
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 832     -1     2     6      3       4  ...       8      2       7      6      11
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 115 Negative = 101
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 442      1     3     9      5       6  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 115 Negative = 102
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1237     -1     3     7      3       4  ...       4      1      10      4       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 116 Negative = 102
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 328      1     2     7      4       5  ...       9      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 116 Negative = 103
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 734      1     7    12      6       6  ...      12      3       5      4       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 117 Negative = 103
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 421      1     4     9      7       7  ...       7      4       6      5       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 118 Negative = 103
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 228      1     3     6      6       4  ...       6      2       6      3       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 119 Negative = 103
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1342     -1    11    15      9       8  ...       4      5      10      4       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 120 Negative = 103
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1499     -1     3     8      5       6  ...       9      2      10      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 120 Negative = 104
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1268     -1     5     9      8       7  ...      10      2       9      3       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 120 Negative = 105
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 110      1     3     8      5       6  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 120 Negative = 106
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 334      1     2     4      4       3  ...       8      2       7      3       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 121 Negative = 106
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 877     -1     3     3      4       4  ...       8      3       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 122 Negative = 106
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1090     -1     5     8      7       6  ...      11      4      10      8       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 122 Negative = 107
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1002     -1     4     3      4       5  ...       8      6       8      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 122 Negative = 108
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 149      1     3     6      5       8  ...       8      3       7      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 122 Negative = 109
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 586      1     5     8      8       7  ...       9      8       6      4       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 123 Negative = 109
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 268      1     4    10      7       7  ...       8      3       7      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 124 Negative = 109
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1090     -1     5     8      7       6  ...      11      4      10      8       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 125 Negative = 109
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 292      1     6    10      9       8  ...       9      6       8      7       4
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 125 Negative = 110
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 403      1     5    11      4       6  ...      11      3       4      4       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 126 Negative = 110
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 606      1     4    10      7       8  ...       9      3       7      4      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 127 Negative = 110
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 934     -1     6    11      8       8  ...       6      2       8      6       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 128 Negative = 110
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1388     -1     5    11      6       8  ...       6      0       8      9       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 128 Negative = 111
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1167     -1     5     7      7       6  ...       7      9      13      8       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 128 Negative = 112
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 886     -1     2     3      3       2  ...       8      2       8      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 128 Negative = 113
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 301      1     5     7      7       5  ...       8      4       8      9       4
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 128 Negative = 114
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 783      1     3     7      5       5  ...       8      2       6      4       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 129 Negative = 114
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 61      1     1     0      2       0  ...       8      1       6      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 130 Negative = 114
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 860     -1     3     5      4       6  ...       8      2       9      4       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 131 Negative = 114
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 248      1     4    11      6       8  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 131 Negative = 115
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1278     -1     4     7      5       6  ...      10      3       8      5       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 132 Negative = 115
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1281     -1     5     7      6       5  ...       7      3       8      3       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 132 Negative = 116
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 563      1     2     2      4       4  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 132 Negative = 117
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 148      1     2     7      4       5  ...       9      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 133 Negative = 117
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 835     -1     4    10      5       8  ...       4      1       6      1       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 134 Negative = 117
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1268     -1     5     9      8       7  ...      10      2       9      3       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 134 Negative = 118
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1112     -1     3     8      5       6  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 134 Negative = 119
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1446     -1     2     1      3       2  ...       7      6       5      1       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 134 Negative = 120
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1390     -1     6    10      8       7  ...       7      1       9      6       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 134 Negative = 121
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 445      1     3     6      6       4  ...       6      2       6      4       6
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 134 Negative = 122
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1438     -1     6     9      8       7  ...      11      0       8      4       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 135 Negative = 122
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1195     -1     4     6      5       9  ...       6      5      10      5       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 135 Negative = 123
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 143      1     3     7      5       5  ...       9      2       4      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 135 Negative = 124
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1543     -1     3     6      4       4  ...       9      3       8      4       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 136 Negative = 124
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1127     -1     3    10      5       8  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 136 Negative = 125
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 563      1     2     2      4       4  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 136 Negative = 126
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 137      1     4    10      5       5  ...      11      6       5      5      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 137 Negative = 126
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1035     -1    10    13     10       8  ...       7      9      12      1       6
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 138 Negative = 126
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 828     -1     1     3      2       2  ...       7      2       8      8       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 138 Negative = 127
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 540      1     2     7      4       5  ...       9      2       6      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 138 Negative = 128
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 154      1     6    14      6       8  ...      11      5       3      4      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 139 Negative = 128
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 985     -1     3     7      4       5  ...      10      2       8      5       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 140 Negative = 128
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1455     -1     5     8      7       6  ...       9      3       8      3       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 129
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1550     -1     1    10      0       8  ...       8      0       8      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 130
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1446     -1     2     1      3       2  ...       7      6       5      1       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 131
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1122     -1     3     7      3       4  ...       4      1      10      4       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 132
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1138     -1     7    14      6       8  ...       5      2       8      5       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 133
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1040     -1     2     6      4       4  ...       8      2      10      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 140 Negative = 134
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 312      1     4    10      7       7  ...       5      3       6      6       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 140 Negative = 135
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 919     -1     5    10      7       7  ...       7      2       8      6      10
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 141 Negative = 135
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 125      1     3     5      5       3  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 141 Negative = 136
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 865     -1     3     9      5       7  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 142 Negative = 136
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1036     -1     6     9      5       5  ...       8      3       6      5       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 142 Negative = 137
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1161     -1     5    11      6       8  ...       4      1      10      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 142 Negative = 138
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 774      1     2     1      3       3  ...       7      2       5      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 142 Negative = 139
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1209     -1     2     3      2       1  ...       9      3      10      1       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 143 Negative = 139
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 38      1     5    13      5       7  ...      11      5       3      4      10
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 143 Negative = 140
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 992     -1     9    11      7       6  ...       5      5      10      4       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 144 Negative = 140
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1474     -1     6     8      5       6  ...       7      4      12      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 144 Negative = 141
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 304      1     4    11      6       8  ...       7      3       6      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 144 Negative = 142
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 484      1     4    11      6       8  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 145 Negative = 142
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1224     -1     6    14      6       8  ...       8      3       9      6      13
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 146 Negative = 142
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1010     -1     4     8      6       6  ...      10      4       8      5       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 146 Negative = 143
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1476     -1     4     6      6       4  ...       8      7      10      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 146 Negative = 144
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 149      1     3     6      5       8  ...       8      3       7      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 146 Negative = 145
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1517     -1     4     6      4       4  ...       8      2      11      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 147 Negative = 145
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 800     -1     5    12      5       6  ...       6      2       9      5       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 147 Negative = 146
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 130      1     2     3      3       2  ...       9      2       5      1       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 147 Negative = 147
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1459     -1     3     5      4       7  ...       8      6       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 148 Negative = 147
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1518     -1     2     2      3       3  ...       8      2       8      6       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 148 Negative = 148
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1194     -1     6    10      8       8  ...      10      5       7      8       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 148 Negative = 149
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1462     -1     2     2      2       4  ...       8      0       8      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 148 Negative = 150
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 376      1     3     5      6       6  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 148 Negative = 151
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 778      1     2     4      3       3  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 149 Negative = 151
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 946     -1     1     0      2       1  ...       8      3      10      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 150 Negative = 151
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1225     -1     5     6      7       9  ...       8      8       9      4       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 150 Negative = 152
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1296     -1     4     4      6       3  ...      10      3       8      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 150 Negative = 153
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1400     -1     2     4      3       2  ...      13      1       9      4      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 150 Negative = 154
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1072     -1     2     3      3       2  ...       5      1      11      2       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 150 Negative = 155
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 656      1     3     7      5       5  ...       9      3       5      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 150 Negative = 156
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 886     -1     2     3      3       2  ...       8      2       8      2       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 151 Negative = 156
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 980     -1     4     8      6       6  ...       8      3      10      5       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 151 Negative = 157
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 945     -1     2     6      3       4  ...       9      1       6      1       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 151 Negative = 158
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1420     -1     4     8      6       6  ...      11      3      10      4       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 151 Negative = 159
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 572      1     6     9      6       5  ...      10      5       3      3      10
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 151 Negative = 160
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 569      1     4    10      5       8  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 152 Negative = 160
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 307      1     5     8      6       6  ...       8      3       7      7       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 153 Negative = 160
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 484      1     4    11      6       8  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 154 Negative = 160
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1095     -1     8    15      8       8  ...       9      5       5      3       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 155 Negative = 160
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 460      1     3    11      5       8  ...       9      2       7      3       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 155 Negative = 161
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 375      1     3     3      5       4  ...       8      3       6      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 156 Negative = 161
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1177     -1     7    11      8       8  ...       9      3      10      8       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 157 Negative = 161
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1126     -1     1     0      1       0  ...       8      2      10      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 157 Negative = 162
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 158      1     3     8      5       6  ...       9      2       6      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 157 Negative = 163
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 774      1     2     1      3       3  ...       7      2       5      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 158 Negative = 163
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 110      1     3     8      5       6  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 159 Negative = 163
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1334     -1     4     8      6       6  ...       8      6       8      3       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 160 Negative = 163
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 750      1     3     8      5       6  ...       9      3       5      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 160 Negative = 164
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1388     -1     5    11      6       8  ...       6      0       8      9       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 161 Negative = 164
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1400     -1     2     4      3       2  ...      13      1       9      4      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 161 Negative = 165
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 991     -1     1     1      1       1  ...      10      3       8      2      10
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 161 Negative = 166
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 653      1     5    13      5       7  ...      11      4       3      4      11
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 161 Negative = 167
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 920     -1     1     0      1       0  ...       8      2       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 162 Negative = 167
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 647      1     8    15      6       8  ...      11      5       5      4       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 162 Negative = 168
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 47      1     3    10      5       8  ...       9      3       5      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 163 Negative = 168
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1338     -1     6    10      8       8  ...       7      8       8      5      12
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 164 Negative = 168
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1033     -1     4     9      5       7  ...       7      3       6      3      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 164 Negative = 169
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 283      1     2     3      3       1  ...       9      1       6      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 164 Negative = 170
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 33      1     3     9      5       7  ...       9      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 165 Negative = 170
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 74      1     4     5      6       8  ...       8      3       7      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 166 Negative = 170
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1002     -1     4     3      4       5  ...       8      6       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 167 Negative = 170
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1085     -1     4     8      5       6  ...      11      3       8      3      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 167 Negative = 171
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 709      1     4     5      6       8  ...       8      3       6      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 167 Negative = 172
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 609      1     5    11      8       8  ...       9      5       7      4       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 168 Negative = 172
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 41      1     3    10      5       7  ...       8      3       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 169 Negative = 172
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 800     -1     5    12      5       6  ...       6      2       9      5       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 170 Negative = 172
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 698      1     2     7      4       4  ...       8      3       7      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 170 Negative = 173
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 800     -1     5    12      5       6  ...       6      2       9      5       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 171 Negative = 173
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1022     -1     5     9      6       7  ...      10      3       8      6       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 171 Negative = 174
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 390      1     3     9      5       7  ...       8      2       7      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 171 Negative = 175
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 807     -1     6    10      9       8  ...       7     10      12      2       5
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 172 Negative = 175
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 40      1     2     7      3       5  ...       8      1       6      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 172 Negative = 176
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 814     -1     7     8     10       7  ...       7     11      10      6       3
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 173 Negative = 176
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1128     -1     7    14      6       8  ...       8      3       7      9      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 173 Negative = 177
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 931     -1     2     6      4       4  ...       9      0       7      1       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 173 Negative = 178
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 910     -1     5     7      8       6  ...       8      6       9      8       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 173 Negative = 179
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 645      1     2     7      4       5  ...       8      2       6      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 173 Negative = 180
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 388      1     3     9      5       7  ...       9      2       6      3       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 174 Negative = 180
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 320      1     2     7      4       4  ...       8      3       6      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 175 Negative = 180
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 913     -1     2     3      4       1  ...       3      1       9      2       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 176 Negative = 180
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 517      1     1     3      3       2  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 176 Negative = 181
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1394     -1     3     8      4       6  ...       6      1       7      7       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 177 Negative = 181
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 632      1     4     7      6       6  ...       8      5       7      4       5
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 177 Negative = 182
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1439     -1     2     7      2       5  ...       8      0       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 178 Negative = 182
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 549      1     3    10      5       7  ...       7      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 178 Negative = 183
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1174     -1     7     8      7       6  ...       7      7      11      2       6
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 179 Negative = 183
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 639      1     5     7      6       5  ...       8      2       8      8       3
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 179 Negative = 184
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1450     -1     2     4      3       5  ...      10      2       9      5       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 180 Negative = 184
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 790     -1     5    11      7       8  ...       9      1       9      6       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 180 Negative = 185
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 625      1     2     1      4       2  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 180 Negative = 186
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 191      1     3     2      5       4  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 181 Negative = 186
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 850     -1     6     8      9       6  ...       8     14       3      4       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 182 Negative = 186
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 696      1     3     9      6       6  ...       9      3       5      3       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 182 Negative = 187
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 965     -1     5    11      7       8  ...       3      1      10      3       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 183 Negative = 187
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1120     -1     2     7      4       5  ...       5      2       8      4       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 183 Negative = 188
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 503      1     1     0      2       0  ...       8      2       6      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 183 Negative = 189
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 327      1     3     9      6       7  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 184 Negative = 189
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1371     -1     5    11      5       8  ...       3      0      10      3       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 185 Negative = 189
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1292     -1    11    14     10       8  ...      10      6       8      4       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 185 Negative = 190
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 34      1     3     3      5       5  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 185 Negative = 191
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1329     -1     4     6      4       8  ...       5      0       8      3       6
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 186 Negative = 191
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 662      1     3     4      5       3  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 186 Negative = 192
# ...
# Positive = 478 Negative = 469
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 96      1     3     6      5       4  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 478 Negative = 470
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 504      1     4     8      6       6  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 479 Negative = 470
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 288      1     4     9      6       6  ...       9      2       6      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 480 Negative = 470
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 251      1     3     6      4       4  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 481 Negative = 470
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 994     -1     5     9      6       8  ...       9      5      10      9      11
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 482 Negative = 470
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 183      1     3     7      5       5  ...      10      2       6      3       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 482 Negative = 471
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 397      1     2     9      4       6  ...       8      2       7      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 483 Negative = 471
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1171     -1     4     5      5       4  ...      11      2      10      5       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 484 Negative = 471
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1267     -1     4     9      6       7  ...       8      3       6      4      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 484 Negative = 472
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 160      1     1     0      2       0  ...       8      2       7      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 484 Negative = 473
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1238     -1     6     9      7       8  ...       8      4      13      9       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 485 Negative = 473
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 66      1     2     4      4       3  ...       9      2       6      2       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 485 Negative = 474
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 12      1     2     2      4       4  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 486 Negative = 474
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 825     -1     2     1      3       3  ...       8      0       7      0       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 487 Negative = 474
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 64      1     3     9      5       7  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 487 Negative = 475
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1488     -1     8    12      8       6  ...       5      4       6      4      10
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 488 Negative = 475
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 136      1     3     4      5       6  ...       8      2       7      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 488 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 662      1     3     4      5       3  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 489 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 227      1     2     3      4       2  ...       8      2       6      2       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 490 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 161      1     3     7      5       4  ...       8      2       7      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 491 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 283      1     2     3      3       1  ...       9      1       6      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 492 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 142      1     6     7      8       6  ...       9      5      10      3       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 493 Negative = 476
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 935     -1     4     7      5       5  ...       9      3       8     10      11
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 494 Negative = 476
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 93      1     3     7      5       5  ...      10      3       5      2       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 494 Negative = 477
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1457     -1     2     1      2       2  ...       7      2      11      1       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 495 Negative = 477
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 894     -1     4     8      6       6  ...      11      3       8      3       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 495 Negative = 478
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1241     -1     3     4      5       3  ...       7      5       8      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 495 Negative = 479
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 571      1     4     9      6       7  ...       8      3       7      3       9
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 495 Negative = 480
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1235     -1     4     5      5       3  ...       9      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 496 Negative = 480
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 419      1     5     9      7       8  ...       9      8       7      4       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 496 Negative = 481
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 653      1     5    13      5       7  ...      11      4       3      4      11
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 497 Negative = 481
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 981     -1     2     7      4       5  ...       6      4       8      5       4
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 498 Negative = 481
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 431      1     3     8      5       6  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 498 Negative = 482
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 224      1     3     3      5       4  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 499 Negative = 482
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 180      1     2     4      3       3  ...       9      1       6      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 500 Negative = 482
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 879     -1     5     9      6       7  ...       9      3       6      5       9
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 501 Negative = 482
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1513     -1     3     7      4       5  ...       8      3       8      0       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 501 Negative = 483
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1137     -1     4     6      6       7  ...       8      3       9      8       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 501 Negative = 484
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 998     -1     2     8      3       6  ...       6      0       7      1       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 501 Negative = 485
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 448      1     2     1      3       1  ...       8      3       6      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 501 Negative = 486
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 95      1     4    11      7       8  ...       8      3       6      3       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 502 Negative = 486
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 880     -1     4     5      5       4  ...       8      3       8      3       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 503 Negative = 486
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 291      1     1     1      2       2  ...       8      1       6      1       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 503 Negative = 487
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1112     -1     3     8      5       6  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 504 Negative = 487
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 223      1     2     5      4       3  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 504 Negative = 488
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 809     -1     3     7      4       5  ...       9      3       8      3       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 505 Negative = 488
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 104      1     2     1      4       2  ...       8      2       6      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 505 Negative = 489
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1125     -1     2     4      3       2  ...       4      1      10      3       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 506 Negative = 489
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 933     -1     2     3      2       2  ...       8      2       9      8       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 506 Negative = 490
# considering     letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 34      1     3     3      5       5  ...       8      2       7      2       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 506 Negative = 491
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1067     -1    10    14      8       8  ...       7      7      13      3       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 507 Negative = 491
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 202      1     4    11      8       8  ...       6      3       8      6       6
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 507 Negative = 492
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 773      1     4     7      6       5  ...       8      2       6      3       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 508 Negative = 492
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 177      1     2     5      4       4  ...       9      2       6      2       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 509 Negative = 492
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1538     -1     4     9      5       6  ...       8      3       9      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 510 Negative = 492
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1436     -1     3     5      5       7  ...       6      2       8      7       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 510 Negative = 493
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1199     -1     3     5      5       4  ...      10      1       6      0       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 510 Negative = 494
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1379     -1     5    10      7       9  ...       9      6      10     10      12
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 510 Negative = 495
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1135     -1     4     8      6       6  ...       8      6       9      7       7
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 510 Negative = 496
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 103      1     4     8      5       6  ...       8      2       7      1       8
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 510 Negative = 497
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1025     -1     4     9      4       7  ...       5      0       8      0       8
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 511 Negative = 497
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1353     -1     5     6      7       5  ...       8     10       8      5       6
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 511 Negative = 498
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 662      1     3     4      5       3  ...       8      2       7      3       7
#
# [1 rows x 17 columns]
# alpha 0.1353352832366127
# Positive = 511 Negative = 499
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 684      1     1     0      2       0  ...       8      1       6      1       8
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 512 Negative = 499
# considering       letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1167     -1     5     7      7       6  ...       7      9      13      8       7
#
# [1 rows x 17 columns]
# alpha 1
# Positive = 513 Negative = 499
# considering      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 835     -1     4    10      5       8  ...       4      1       6      1       5
#
# [1 rows x 17 columns]
# alpha 1.0
# Positive = 513 Negative = 500

# %%
# Markov Sampling Done
# sampled data points are stored in sampled_data
print(len(sampled_data))
dataset = pd.concat(sampled_data)
print(dataset.head())
# Out:
# 798
#      letter  xbox  ybox  width  height  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1016     -1     5     7      5       5  ...       6      6      12      2       5
# 686       1     3     6      5       4  ...       9      2       6      3       8
# 53        1     5    10      5       5  ...      11      4       3      4      10
# 741       1     4     9      5       7  ...       8      2       7      1       8
# 724       1     4     9      6       7  ...       8      2       7      3       6
#
# [5 rows x 17 columns]

# %%
print("In the final dataset on which SVM is being trained ")

print(f"Number of positive samples {len(dataset[dataset['letter']==1])}")
print(f"Number of negative samples {len(dataset[dataset['letter']==-1])}")
features = dataset.loc[:, dataset.columns != 'letter']
target = dataset.loc[:, ['letter']]

print(features.head())
print(target.head())
# Out:
# In the final dataset on which SVM is being trained
# Number of positive samples 300
# Number of negative samples 498
#       xbox  ybox  width  height  onpix  ...  xy2bar  xedge  xedgey  yedge  yedgex
# 1016     5     7      5       5      4  ...       6      6      12      2       5
# 686      3     6      5       4      3  ...       9      2       6      3       8
# 53       5    10      5       5      3  ...      11      4       3      4      10
# 741      4     9      5       7      4  ...       8      2       7      1       8
# 724      4     9      6       7      4  ...       8      2       7      3       6
#
# [5 rows x 16 columns]
#      letter
# 1016     -1
# 686       1
# 53        1
# 741       1
# 724       1

# %%
def hellinger(X1, X2):
  return np.sqrt(np.dot(X1,X2.T))

# %%
# final SVMC algorithm
# scaling the feature matrix values into a td distribution

# X_train = scale(features)
X_train = features
y_train = target
y_train = y_train.astype('int')


# X_test = scale(df_final_test.loc[:, df_final_test.columns != 'letter'])
X_test = df_final_test.loc[:, df_final_test.columns != 'letter']
y_test = df_final_test.loc[:, ['letter']]
y_test = y_test.astype('int')


# model training
import warnings
warnings.filterwarnings("ignore")
kernels = ['linear', 'rbf', 'poly']
for kernel in kernels:
    model = SVC(kernel = kernel)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_true = y_test, y_pred = y_pred)
    print(f"Kernel = {kernel}, accuracy = {acc * 100}")

model = SVC(kernel = hellinger)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_true = y_test, y_pred = y_pred)
print(f"Kernel = hellinger, accuracy = {acc * 100}")

model = SVC(kernel = chi2_kernel)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
acc = accuracy_score(y_true = y_test, y_pred = y_pred)
print(f"Kernel = chi2_kernel, accuracy = {acc * 100}")
# Out:
# Kernel = linear, accuracy = 95.51282051282051
# Kernel = rbf, accuracy = 95.72649572649573
# Kernel = poly, accuracy = 95.94017094017094
# Kernel = hellinger, accuracy = 93.58974358974359
# Kernel = chi2_kernel, accuracy = 94.87179487179486
